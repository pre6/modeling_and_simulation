# %% [markdown]
# # Understanding Joint distributions and Marginal Distributions

# %% [markdown]
# ## Overall Goal
#
# The overall goal of this notebook its to very intuitivley understand how marginal distributions are derived from joint distributions.
#
# ### 1) Contruct a generic joint distribution of a genric normal bivariate distribution

# %%
import numpy as np
import matplotlib.pyplot as plt

# ---- Grid ----
x = np.linspace(-5, 5, 300)
y = np.linspace(-5, 5, 300)
X, Y = np.meshgrid(x, y)

# ---- Define two non-Gaussian blobs ----
# Blob 1: narrow in x, wide in y, tilted
Z1 = np.exp(
    -((X + 1.5)**2) / 0.5
    -((Y - 1.0 - 0.5 * X)**2) / 2.5
)

# Blob 2: wide in x, narrow in y
Z2 = np.exp(
    -((X - 2.0)**2) / 3.0
    -((Y + 1.5)**2) / 0.4
)

# ---- Mixture ----
Z = 0.6 * Z1 + 0.4 * Z2

# ---- Normalize to make it a valid joint distribution ----
dx = x[1] - x[0]
dy = y[1] - y[0]
Z /= Z.sum() * dx * dy   # now ∫∫ P(x,y) dx dy = 1

# ---- Plot 3D surface ----
fig = plt.figure(figsize=(9, 7))
ax = fig.add_subplot(111, projection="3d")

ax.plot_surface(
    X, Y, Z,
    cmap="plasma",
    linewidth=0,
    antialiased=True
)

ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_zlabel("P(x, y)")
ax.set_title("Non-Gaussian Joint Distribution (Mixture)")

plt.show()

# %% [markdown]
# ### 2) Look at slices of the 3d plot

# %%
# ---- Pick 4 random y-slices ----

np.random.seed(123)

indices = np.random.choice(len(y), size=4, replace=False)

# ---- Plot ----
plt.figure(figsize=(8, 5))

for i in indices:
    x_slice = X[i, :]# all x at fixed y
    z_slice = Z[i, :]# pdf values at that y
    y_value = y[i]

    plt.plot(x_slice, z_slice, label=f"y = {y_value:.2f}")

plt.xlabel("x")
plt.ylabel("f(x, y)")
plt.title("Slices of Joint PDF at Random y-values")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# For each of these y values, there exists a slice of x at that point. The **Marginal Distribution** is the sum of all the probabilities at this slice. So let's do that now

# %% [markdown]
# ### 3) Marginal distribution at the y values

# %%
# print(indices)

marginal_distributions_of_y = []

dx = x[1] - x[0] # this is how spaces out the points are

for i in indices: # you are summing over all the x values at a specfic y
    x_slice = X[i, :]# all x at fixed y
    z_slice = Z[i, :]# pdf values at that y
    y_value = y[i]
    
    marginal_distribution_y = 0
    
    for value in z_slice:
        marginal_distribution_y += value * dx

    marginal_distributions_of_y.append([y_value,marginal_distribution_y,i])

# %%
for i in marginal_distributions_of_y:
    print(f"For the y value {i[0]} the sum of all the probabilies is {i[1]} at index {i[2]}")
# Out:
# For the y value 3.7625418060200673 the sum of all the probabilies is 0.0019207240138085536 at index 262
# For the y value -1.1872909698996659 the sum of all the probabilies is 0.3710216144507227 at index 114
# For the y value 0.5183946488294309 the sum of all the probabilies is 0.20551024837870835 at index 165
# For the y value 4.297658862876254 the sum of all the probabilies is 0.0004112821410439687 at index 278

# %% [markdown]
# Now lets do it for all the y values not just these four:

# %%
# Marginal of Y from joint PDF Z(x,y)

import numpy as np
import matplotlib.pyplot as plt

# instead of a for loop we can use the sum function
marginal_y = np.sum(Z, axis=0) * dy   # sum over y

# Plot marginal of Y
plt.figure()
plt.plot(y, marginal_y)
plt.xlabel("y")
plt.ylabel("p(y)")
plt.title("Marginal Distribution of y")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Is this a probability distribution; does the area under the curve add up to one?
#
# Short answer yes it is!! This is because in the three dimentional plot, all of the probailities add up to one. when you consider marginal distribution, you are add up like half of the probabilties. The rest when added up will still equal one.
